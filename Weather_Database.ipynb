# %%
# Dependencies and setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description,
                          "Country": city_country})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | abalak
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | puerto carreno
# Processing Record 8 of Set 1 | eagan
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | vodyane
# Processing Record 11 of Set 1 | taltal
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | irtyshskiy
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | pedro ii
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | port moresby
# Processing Record 27 of Set 1 | marsh harbour
# Processing Record 28 of Set 1 | stornoway
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | shenjiamen
# Processing Record 36 of Set 1 | srednekolymsk
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | tuy hoa
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | akyab
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | ridgecrest
# Processing Record 46 of Set 1 | waverly
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | mandalgovi
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 2 | sivaki
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | zhigansk
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 2 | yumen
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | yuanping
# Processing Record 11 of Set 2 | concarneau
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | roncesvalles
# Processing Record 17 of Set 2 | sindor
# Processing Record 18 of Set 2 | najran
# Processing Record 19 of Set 2 | dandong
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | rawlins
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | ambilobe
# Processing Record 24 of Set 2 | seoul
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | mount gambier
# Processing Record 27 of Set 2 | atar
# Processing Record 28 of Set 2 | chapais
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | tasca
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | maceio
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | sioux lookout
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | ndele
# Processing Record 45 of Set 2 | brae
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | cabedelo
# Processing Record 49 of Set 2 | ribeira brava
# Processing Record 50 of Set 2 | prokuplje
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | morgan city
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | disna
# Processing Record 5 of Set 3 | general cepeda
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | port hardy
# Processing Record 9 of Set 3 | tselinnoye
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | la baneza
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | dingolfing
# Processing Record 18 of Set 3 | marawi
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | glenwood springs
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | panguna
# Processing Record 27 of Set 3 | bloomfield
# Processing Record 28 of Set 3 | karratha
# Processing Record 29 of Set 3 | urumqi
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | sembakung
# Processing Record 34 of Set 3 | shahpur
# Processing Record 35 of Set 3 | puerto leguizamo
# Processing Record 36 of Set 3 | cabo san lucas
# Processing Record 37 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 38 of Set 3 | gelemso
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | tecoanapa
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | zima
# Processing Record 44 of Set 3 | moengo
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | la paz
# Processing Record 47 of Set 3 | beringovskiy
# Processing Record 48 of Set 3 | laramie
# Processing Record 49 of Set 3 | parati
# Processing Record 50 of Set 3 | galle
# Processing Record 1 of Set 4 | tigre
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | yakeshi
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | saskylakh
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | aken
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | kathu
# Processing Record 12 of Set 4 | batemans bay
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | kieta
# Processing Record 15 of Set 4 | awjilah
# Processing Record 16 of Set 4 | prieska
# Processing Record 17 of Set 4 | rehoboth
# Processing Record 18 of Set 4 | presidencia roque saenz pena
# Processing Record 19 of Set 4 | labuhan
# Processing Record 20 of Set 4 | ekhabi
# Processing Record 21 of Set 4 | kandrian
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | lagoa
# Processing Record 24 of Set 4 | bambanglipuro
# Processing Record 25 of Set 4 | siderno
# Processing Record 26 of Set 4 | george town
# Processing Record 27 of Set 4 | leshukonskoye
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | kenai
# Processing Record 30 of Set 4 | gorin
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | tamasane
# Processing Record 34 of Set 4 | honningsvag
# Processing Record 35 of Set 4 | indramayu
# Processing Record 36 of Set 4 | georgiyevka
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | matadi
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | hobart
# Processing Record 41 of Set 4 | shitanjing
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | hun
# Processing Record 45 of Set 4 | la ronge
# Processing Record 46 of Set 4 | tipuani
# Processing Record 47 of Set 4 | catia la mar
# Processing Record 48 of Set 4 | blagoyevo
# Processing Record 49 of Set 4 | nouadhibou
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | takoradi
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | mar del plata
# Processing Record 5 of Set 5 | darab
# Processing Record 6 of Set 5 | hay river
# Processing Record 7 of Set 5 | campos belos
# Processing Record 8 of Set 5 | polson
# Processing Record 9 of Set 5 | gunupur
# Processing Record 10 of Set 5 | arman
# Processing Record 11 of Set 5 | kromy
# Processing Record 12 of Set 5 | jamestown
# Processing Record 13 of Set 5 | riverton
# Processing Record 14 of Set 5 | pangody
# Processing Record 15 of Set 5 | dubrovytsya
# Processing Record 16 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 5 | castro
# Processing Record 18 of Set 5 | bayji
# Processing Record 19 of Set 5 | menongue
# Processing Record 20 of Set 5 | wahiawa
# Processing Record 21 of Set 5 | bharatpur
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | tuktoyaktuk
# Processing Record 24 of Set 5 | sterling
# Processing Record 25 of Set 5 | newport
# Processing Record 26 of Set 5 | puerto del rosario
# Processing Record 27 of Set 5 | komsomolskiy
# Processing Record 28 of Set 5 | hokitika
# Processing Record 29 of Set 5 | namibe
# Processing Record 30 of Set 5 | cam ranh
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | huicheng
# Processing Record 33 of Set 5 | mongomo
# Processing Record 34 of Set 5 | port hedland
# Processing Record 35 of Set 5 | chumikan
# Processing Record 36 of Set 5 | bandundu
# Processing Record 37 of Set 5 | batagay-alyta
# Processing Record 38 of Set 5 | kopidlno
# Processing Record 39 of Set 5 | rivadavia
# Processing Record 40 of Set 5 | beian
# Processing Record 41 of Set 5 | novyy urengoy
# Processing Record 42 of Set 5 | pauini
# Processing Record 43 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 5 | mandiana
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | conceicao do araguaia
# Processing Record 47 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 5 | filadelfia
# Processing Record 49 of Set 5 | bell ville
# Processing Record 50 of Set 5 | narsaq
# Processing Record 1 of Set 6 | tessalit
# Processing Record 2 of Set 6 | chikodi
# Processing Record 3 of Set 6 | cayenne
# Processing Record 4 of Set 6 | egvekinot
# Processing Record 5 of Set 6 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | salinopolis
# Processing Record 7 of Set 6 | bonfim
# Processing Record 8 of Set 6 | uspenskaya
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | maniwaki
# Processing Record 11 of Set 6 | san cristobal
# Processing Record 12 of Set 6 | sao joao da barra
# Processing Record 13 of Set 6 | milagro
# Processing Record 14 of Set 6 | alice springs
# Processing Record 15 of Set 6 | san luis
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | maniitsoq
# Processing Record 19 of Set 6 | sainte-suzanne
# Processing Record 20 of Set 6 | gibgos
# Processing Record 21 of Set 6 | ilulissat
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | mackay
# Processing Record 24 of Set 6 | dombasle-sur-meurthe
# Processing Record 25 of Set 6 | mehamn
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | barahona
# Processing Record 28 of Set 6 | nyurba
# Processing Record 29 of Set 6 | gravdal
# Processing Record 30 of Set 6 | asmara
# Processing Record 31 of Set 6 | pandhana
# Processing Record 32 of Set 6 | poronaysk
# Processing Record 33 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 6 | leh
# Processing Record 35 of Set 6 | hasaki
# Processing Record 36 of Set 6 | kattivakkam
# Processing Record 37 of Set 6 | imeni zhelyabova
# Processing Record 38 of Set 6 | douentza
# Processing Record 39 of Set 6 | burns lake
# Processing Record 40 of Set 6 | matara
# Processing Record 41 of Set 6 | alofi
# Processing Record 42 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | nhulunbuy
# Processing Record 44 of Set 6 | marsa matruh
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | kidal
# Processing Record 47 of Set 6 | buala
# Processing Record 48 of Set 6 | peyima
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 50 of Set 6 | mayo
# Processing Record 1 of Set 7 | fengxian
# Processing Record 2 of Set 7 | quimper
# Processing Record 3 of Set 7 | leiyang
# Processing Record 4 of Set 7 | opuwo
# Processing Record 5 of Set 7 | wenzhou
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | saint-augustin
# Processing Record 8 of Set 7 | luanda
# Processing Record 9 of Set 7 | mizan teferi
# Processing Record 10 of Set 7 | rezh
# Processing Record 11 of Set 7 | alyangula
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | bud
# Processing Record 14 of Set 7 | pegnitz
# Processing Record 15 of Set 7 | valdosta
# Processing Record 16 of Set 7 | khorixas
# Processing Record 17 of Set 7 | savonlinna
# Processing Record 18 of Set 7 | verkhnevilyuysk
# Processing Record 19 of Set 7 | zhuhai
# Processing Record 20 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 7 | chegdomyn
# Processing Record 22 of Set 7 | toungoo
# City not found. Skipping...
# Processing Record 23 of Set 7 | hope
# Processing Record 24 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 7 | camuy
# Processing Record 26 of Set 7 | pevek
# Processing Record 27 of Set 7 | port macquarie
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | college
# Processing Record 30 of Set 7 | kaitangata
# Processing Record 31 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 7 | worland
# Processing Record 33 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 7 | darasun
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | bismarck
# Processing Record 37 of Set 7 | charters towers
# Processing Record 38 of Set 7 | aykhal
# Processing Record 39 of Set 7 | kutum
# Processing Record 40 of Set 7 | zenzeli
# Processing Record 41 of Set 7 | valparaiso
# Processing Record 42 of Set 7 | geraldton
# Processing Record 43 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 7 | sonoita
# Processing Record 45 of Set 7 | surt
# Processing Record 46 of Set 7 | lahij
# Processing Record 47 of Set 7 | bardiyah
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 7 | ponta do sol
# Processing Record 1 of Set 8 | karasburg
# Processing Record 2 of Set 8 | fort dodge
# Processing Record 3 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 8 | great falls
# Processing Record 5 of Set 8 | camacari
# Processing Record 6 of Set 8 | mazagao
# Processing Record 7 of Set 8 | plettenberg bay
# Processing Record 8 of Set 8 | asfi
# Processing Record 9 of Set 8 | kahului
# Processing Record 10 of Set 8 | domoni
# Processing Record 11 of Set 8 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | balaguer
# Processing Record 14 of Set 8 | luancheng
# Processing Record 15 of Set 8 | manjacaze
# Processing Record 16 of Set 8 | koutiala
# Processing Record 17 of Set 8 | salamiyah
# Processing Record 18 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | cadillac
# Processing Record 21 of Set 8 | santo amaro da imperatriz
# Processing Record 22 of Set 8 | santa isabel do rio negro
# Processing Record 23 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 8 | methoni
# Processing Record 25 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 8 | muramvya
# Processing Record 27 of Set 8 | shimoda
# Processing Record 28 of Set 8 | baruun-urt
# Processing Record 29 of Set 8 | sao filipe
# Processing Record 30 of Set 8 | bilibino
# Processing Record 31 of Set 8 | chincha alta
# Processing Record 32 of Set 8 | hofn
# Processing Record 33 of Set 8 | hovd
# Processing Record 34 of Set 8 | okhotsk
# Processing Record 35 of Set 8 | muravlenko
# Processing Record 36 of Set 8 | rhyl
# Processing Record 37 of Set 8 | verkh-usugli
# Processing Record 38 of Set 8 | winona
# Processing Record 39 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 8 | ouadda
# Processing Record 41 of Set 8 | asau
# Processing Record 42 of Set 8 | dossor
# Processing Record 43 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 8 | suez
# Processing Record 45 of Set 8 | vestmannaeyjar
# Processing Record 46 of Set 8 | limon
# Processing Record 47 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 8 | medina
# Processing Record 49 of Set 8 | ust-kut
# Processing Record 50 of Set 8 | ayagoz
# Processing Record 1 of Set 9 | bubaque
# Processing Record 2 of Set 9 | luoyang
# Processing Record 3 of Set 9 | khash
# Processing Record 4 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 9 | payson
# Processing Record 6 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 9 | walvis bay
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | norsup
# Processing Record 10 of Set 9 | port blair
# Processing Record 11 of Set 9 | janakpur
# Processing Record 12 of Set 9 | constitucion
# Processing Record 13 of Set 9 | berdigestyakh
# Processing Record 14 of Set 9 | avera
# Processing Record 15 of Set 9 | teguise
# Processing Record 16 of Set 9 | kandi
# Processing Record 17 of Set 9 | craig
# Processing Record 18 of Set 9 | coahuayana
# Processing Record 19 of Set 9 | amuntai
# Processing Record 20 of Set 9 | zambezi
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | bonthe
# Processing Record 23 of Set 9 | maunabo
# Processing Record 24 of Set 9 | sirfa
# City not found. Skipping...
# Processing Record 25 of Set 9 | qandala
# Processing Record 26 of Set 9 | carutapera
# Processing Record 27 of Set 9 | santa maria
# Processing Record 28 of Set 9 | lazaro cardenas
# Processing Record 29 of Set 9 | bunia
# Processing Record 30 of Set 9 | gerash
# Processing Record 31 of Set 9 | yatou
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | sur
# Processing Record 34 of Set 9 | tual
# Processing Record 35 of Set 9 | balabac
# Processing Record 36 of Set 9 | mersing
# Processing Record 37 of Set 9 | vila franca do campo
# Processing Record 38 of Set 9 | bandarbeyla
# Processing Record 39 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 9 | we
# City not found. Skipping...
# Processing Record 42 of Set 9 | indian head
# Processing Record 43 of Set 9 | guerrero negro
# Processing Record 44 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 9 | innisfail
# Processing Record 46 of Set 9 | roma
# Processing Record 47 of Set 9 | qui nhon
# Processing Record 48 of Set 9 | auki
# Processing Record 49 of Set 9 | albert lea
# Processing Record 50 of Set 9 | selma
# Processing Record 1 of Set 10 | yaan
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | sovetskaya
# Processing Record 4 of Set 10 | berberati
# Processing Record 5 of Set 10 | son la
# Processing Record 6 of Set 10 | poland
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | oistins
# Processing Record 9 of Set 10 | chuzhou
# Processing Record 10 of Set 10 | dubai
# Processing Record 11 of Set 10 | kargopol
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | korla
# Processing Record 14 of Set 10 | port augusta
# Processing Record 15 of Set 10 | soe
# Processing Record 16 of Set 10 | virginia beach
# Processing Record 17 of Set 10 | henties bay
# Processing Record 18 of Set 10 | nelson bay
# Processing Record 19 of Set 10 | bereda
# Processing Record 20 of Set 10 | khrebtovaya
# Processing Record 21 of Set 10 | ostrovnoy
# Processing Record 22 of Set 10 | upata
# Processing Record 23 of Set 10 | padre bernardo
# Processing Record 24 of Set 10 | ocean springs
# Processing Record 25 of Set 10 | boshnyakovo
# Processing Record 26 of Set 10 | brindisi
# Processing Record 27 of Set 10 | burnie
# Processing Record 28 of Set 10 | kollo
# Processing Record 29 of Set 10 | rongai
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | bajil
# Processing Record 32 of Set 10 | rio cuarto
# Processing Record 33 of Set 10 | te anau
# Processing Record 34 of Set 10 | kutina
# Processing Record 35 of Set 10 | kaka
# Processing Record 36 of Set 10 | antofagasta
# Processing Record 37 of Set 10 | borogontsy
# Processing Record 38 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 10 | tura
# Processing Record 40 of Set 10 | weyburn
# Processing Record 41 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 42 of Set 10 | abonnema
# Processing Record 43 of Set 10 | pak thong chai
# Processing Record 44 of Set 10 | kloulklubed
# Processing Record 45 of Set 10 | vao
# Processing Record 46 of Set 10 | buraydah
# Processing Record 47 of Set 10 | alihe
# Processing Record 48 of Set 10 | kilindoni
# Processing Record 49 of Set 10 | grand gaube
# Processing Record 50 of Set 10 | conakry
# Processing Record 1 of Set 11 | paamiut
# Processing Record 2 of Set 11 | salalah
# Processing Record 3 of Set 11 | monrovia
# Processing Record 4 of Set 11 | xuanhua
# Processing Record 5 of Set 11 | saint-joseph
# Processing Record 6 of Set 11 | ambulu
# Processing Record 7 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 11 | mount hagen
# Processing Record 9 of Set 11 | mayumba
# Processing Record 10 of Set 11 | evensk
# Processing Record 11 of Set 11 | pyapon
# Processing Record 12 of Set 11 | bay roberts
# Processing Record 13 of Set 11 | preobrazheniye
# Processing Record 14 of Set 11 | grindavik
# Processing Record 15 of Set 11 | birjand
# Processing Record 16 of Set 11 | sobolevo
# Processing Record 17 of Set 11 | orange cove
# Processing Record 18 of Set 11 | ahuimanu
# Processing Record 19 of Set 11 | aleksandrov gay
# Processing Record 20 of Set 11 | istra
# Processing Record 21 of Set 11 | christchurch
# Processing Record 22 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 23 of Set 11 | tamiahua
# Processing Record 24 of Set 11 | bathsheba
# Processing Record 25 of Set 11 | juneau
# Processing Record 26 of Set 11 | piotrkow trybunalski
# Processing Record 27 of Set 11 | heyang
# Processing Record 28 of Set 11 | keti bandar
# Processing Record 29 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 11 | fairbanks
# Processing Record 31 of Set 11 | bianzhuang
# Processing Record 32 of Set 11 | kawalu
# Processing Record 33 of Set 11 | mbandaka
# Processing Record 34 of Set 11 | kavaratti
# Processing Record 35 of Set 11 | gazojak
# Processing Record 36 of Set 11 | lebedinyy
# Processing Record 37 of Set 11 | berlevag
# Processing Record 38 of Set 11 | shingu
# Processing Record 39 of Set 11 | shangrao
# Processing Record 40 of Set 11 | losal
# Processing Record 41 of Set 11 | benguela
# Processing Record 42 of Set 11 | zhangye
# Processing Record 43 of Set 11 | odweyne
# Processing Record 44 of Set 11 | arlit
# Processing Record 45 of Set 11 | dawson creek
# Processing Record 46 of Set 11 | ambon
# Processing Record 47 of Set 11 | nizwa
# Processing Record 48 of Set 11 | baependi
# Processing Record 49 of Set 11 | sambava
# Processing Record 50 of Set 11 | poum
# Processing Record 1 of Set 12 | anadyr
# Processing Record 2 of Set 12 | coro
# Processing Record 3 of Set 12 | emerald
# Processing Record 4 of Set 12 | tarskoye
# Processing Record 5 of Set 12 | altamira
# Processing Record 6 of Set 12 | laguna
# Processing Record 7 of Set 12 | ormara
# Processing Record 8 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 9 of Set 12 | isangel
# Processing Record 10 of Set 12 | inirida
# Processing Record 11 of Set 12 | ixtapa
# Processing Record 12 of Set 12 | ladario
# Processing Record 13 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 12 | oneonta
# Processing Record 15 of Set 12 | douglas
# Processing Record 16 of Set 12 | guasdualito
# Processing Record 17 of Set 12 | bowen
# Processing Record 18 of Set 12 | yar-sale
# Processing Record 19 of Set 12 | hami
# Processing Record 20 of Set 12 | maumere
# Processing Record 21 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 12 | port-cartier
# Processing Record 23 of Set 12 | manado
# Processing Record 24 of Set 12 | mayor pablo lagerenza
# Processing Record 25 of Set 12 | colac
# Processing Record 26 of Set 12 | loralai
# Processing Record 27 of Set 12 | aripuana
# Processing Record 28 of Set 12 | frederico westphalen
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | rovaniemi
# Processing Record 31 of Set 12 | puerto madryn
# Processing Record 32 of Set 12 | viedma
# Processing Record 33 of Set 12 | fereydunshahr
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | nicoya
# Processing Record 36 of Set 12 | naryan-mar
# Processing Record 37 of Set 12 | sungai padi
# Processing Record 38 of Set 12 | santa barbara
# Processing Record 39 of Set 12 | nsanje
# Processing Record 40 of Set 12 | chicama
# Processing Record 41 of Set 12 | kirakira
# Processing Record 42 of Set 12 | matai
# Processing Record 43 of Set 12 | teya
# Processing Record 44 of Set 12 | novo cruzeiro
# Processing Record 45 of Set 12 | itoman
# Processing Record 46 of Set 12 | ha giang
# Processing Record 47 of Set 12 | badou
# Processing Record 48 of Set 12 | macamic
# Processing Record 49 of Set 12 | bambous virieux
# Processing Record 50 of Set 12 | cooma
# Processing Record 1 of Set 13 | sandy bay
# Processing Record 2 of Set 13 | ucluelet
# Processing Record 3 of Set 13 | umm lajj
# Processing Record 4 of Set 13 | itupiranga
# Processing Record 5 of Set 13 | pozo colorado
# Processing Record 6 of Set 13 | puerto escondido
# Processing Record 7 of Set 13 | sept-iles
# Processing Record 8 of Set 13 | sabha
# Processing Record 9 of Set 13 | urubicha
# Processing Record 10 of Set 13 | rio gallegos
# Processing Record 11 of Set 13 | ancud
# Processing Record 12 of Set 13 | colares
# Processing Record 13 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 14 of Set 13 | tsiroanomandidy
# Processing Record 15 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 16 of Set 13 | porto real
# Processing Record 17 of Set 13 | chara
# Processing Record 18 of Set 13 | hobyo
# Processing Record 19 of Set 13 | kuching
# Processing Record 20 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 13 | shache
# Processing Record 22 of Set 13 | madras
# Processing Record 23 of Set 13 | sechura
# Processing Record 24 of Set 13 | biak
# Processing Record 25 of Set 13 | ratnagiri
# Processing Record 26 of Set 13 | bukama
# Processing Record 27 of Set 13 | ko samui
# Processing Record 28 of Set 13 | leningradskiy
# Processing Record 29 of Set 13 | luderitz
# Processing Record 30 of Set 13 | lodwar
# Processing Record 31 of Set 13 | santa cruz de tenerife
# Processing Record 32 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 13 | ust-barguzin
# Processing Record 34 of Set 13 | san vicente
# Processing Record 35 of Set 13 | san jose
# Processing Record 36 of Set 13 | tanem
# Processing Record 37 of Set 13 | lorengau
# Processing Record 38 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 39 of Set 13 | the valley
# Processing Record 40 of Set 13 | kyabe
# Processing Record 41 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 13 | nosy varika
# Processing Record 43 of Set 13 | de aar
# Processing Record 44 of Set 13 | pacific grove
# Processing Record 45 of Set 13 | atlantic city
# Processing Record 46 of Set 13 | grand-lahou
# Processing Record 47 of Set 13 | asbury park
# Processing Record 48 of Set 13 | prince rupert
# Processing Record 49 of Set 13 | praia
# Processing Record 50 of Set 13 | foca
# Processing Record 1 of Set 14 | antonovo
# Processing Record 2 of Set 14 | toledo
# Processing Record 3 of Set 14 | lalmohan
# Processing Record 4 of Set 14 | calama
# Processing Record 5 of Set 14 | raudeberg
# Processing Record 6 of Set 14 | vanimo
# Processing Record 7 of Set 14 | la quinta
# Processing Record 8 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 9 of Set 14 | pinotepa nacional
# Processing Record 10 of Set 14 | zabol
# Processing Record 11 of Set 14 | nushki
# Processing Record 12 of Set 14 | sao geraldo do araguaia
# Processing Record 13 of Set 14 | green river
# Processing Record 14 of Set 14 | balakhninskiy
# Processing Record 15 of Set 14 | rawson
# Processing Record 16 of Set 14 | chokwe
# Processing Record 17 of Set 14 | xining
# Processing Record 18 of Set 14 | mayahi
# Processing Record 19 of Set 14 | spetsai
# City not found. Skipping...
# Processing Record 20 of Set 14 | muros
# Processing Record 21 of Set 14 | amapa
# Processing Record 22 of Set 14 | sisimiut
# Processing Record 23 of Set 14 | alta floresta
# Processing Record 24 of Set 14 | faribault
# Processing Record 25 of Set 14 | chitral
# Processing Record 26 of Set 14 | mikhaylovka
# Processing Record 27 of Set 14 | nishihara
# Processing Record 28 of Set 14 | sao jose da coroa grande
# Processing Record 29 of Set 14 | nautla
# Processing Record 30 of Set 14 | finschhafen
# Processing Record 31 of Set 14 | aksarka
# Processing Record 32 of Set 14 | villa guerrero
# Processing Record 33 of Set 14 | mubende
# Processing Record 34 of Set 14 | kachiry
# Processing Record 35 of Set 14 | anchorage
# Processing Record 36 of Set 14 | springbok
# Processing Record 37 of Set 14 | zaraza
# Processing Record 38 of Set 14 | guangyuan
# Processing Record 39 of Set 14 | ayan
# Processing Record 40 of Set 14 | sorland
# Processing Record 41 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 14 | jalingo
# Processing Record 43 of Set 14 | kharitonovo
# Processing Record 44 of Set 14 | machinga
# Processing Record 45 of Set 14 | hihya
# Processing Record 46 of Set 14 | lashio
# Processing Record 47 of Set 14 | tutoia
# Processing Record 48 of Set 14 | san pedro
# Processing Record 49 of Set 14 | mama
# Processing Record 50 of Set 14 | bida
# Processing Record 1 of Set 15 | turkistan
# Processing Record 2 of Set 15 | hommelvik
# Processing Record 3 of Set 15 | havoysund
# Processing Record 4 of Set 15 | strezhevoy
# Processing Record 5 of Set 15 | bolobo
# Processing Record 6 of Set 15 | kaoma
# Processing Record 7 of Set 15 | hvolsvollur
# Processing Record 8 of Set 15 | salimpur
# Processing Record 9 of Set 15 | maryborough
# Processing Record 10 of Set 15 | iquitos
# Processing Record 11 of Set 15 | palmer
# Processing Record 12 of Set 15 | curico
# Processing Record 13 of Set 15 | soroti
# Processing Record 14 of Set 15 | gat
# Processing Record 15 of Set 15 | kabugao
# Processing Record 16 of Set 15 | sangar
# Processing Record 17 of Set 15 | fukue
# Processing Record 18 of Set 15 | paita
# Processing Record 19 of Set 15 | tombouctou
# Processing Record 20 of Set 15 | saa
# Processing Record 21 of Set 15 | pergamino
# Processing Record 22 of Set 15 | nikel
# Processing Record 23 of Set 15 | champerico
# Processing Record 24 of Set 15 | arcos de la frontera
# Processing Record 25 of Set 15 | dhangadhi
# Processing Record 26 of Set 15 | necochea
# Processing Record 27 of Set 15 | pemba
# Processing Record 28 of Set 15 | luena
# Processing Record 29 of Set 15 | cururupu
# Processing Record 30 of Set 15 | warrnambool
# Processing Record 31 of Set 15 | saveh
# Processing Record 32 of Set 15 | mali
# Processing Record 33 of Set 15 | sarangani
# Processing Record 34 of Set 15 | lixourion
# Processing Record 35 of Set 15 | broome
# Processing Record 36 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 15 | sandavagur
# City not found. Skipping...
# Processing Record 38 of Set 15 | iriron
# City not found. Skipping...
# Processing Record 39 of Set 15 | ugoofaaru
# Processing Record 40 of Set 15 | lubao
# Processing Record 41 of Set 15 | beya
# Processing Record 42 of Set 15 | conchas
# Processing Record 43 of Set 15 | katherine
# Processing Record 44 of Set 15 | nizhniy chir
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora  -0.7393  -90.3518     82.40        69          20
# 1          Atuona  -9.8000 -139.0333     79.99        73          44
# 2          Abalak  58.1286   68.5944     40.69        65          27
# 3          Albany  42.6001  -73.9662     57.99        48          86
# 4       Mahebourg -20.4081   57.7000     77.00        88          75
# 5  Saint-Philippe -21.3585   55.7679     77.00        73           0
# 6  Puerto Carreno   6.1890  -67.4859     81.12        77         100
# 7           Eagan  44.8041  -93.1669     43.00        56          90
# 8        Tasiilaq  65.6145  -37.6368     37.40        81          90
# 9         Vodyane  47.4875   34.4924     46.47        66         100
#
#    Wind Speed Weather Description Country
# 0       16.11          few clouds      EC
# 1       15.03    scattered clouds      PF
# 2        9.53    scattered clouds      RU
# 3        1.01     overcast clouds      US
# 4       14.97          light rain      MU
# 5       19.57          light rain      RE
# 6       14.83     overcast clouds      CO
# 7       14.97     overcast clouds      US
# 8       14.97          light rain      GL
# 9        8.99     overcast clouds      UA

# %%
# Set new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Set dataframe to accept new column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora      EC  -0.7393  -90.3518     82.40        69          20
# 1          Atuona      PF  -9.8000 -139.0333     79.99        73          44
# 2          Abalak      RU  58.1286   68.5944     40.69        65          27
# 3          Albany      US  42.6001  -73.9662     57.99        48          86
# 4       Mahebourg      MU -20.4081   57.7000     77.00        88          75
# 5  Saint-Philippe      RE -21.3585   55.7679     77.00        73           0
# 6  Puerto Carreno      CO   6.1890  -67.4859     81.12        77         100
# 7           Eagan      US  44.8041  -93.1669     43.00        56          90
# 8        Tasiilaq      GL  65.6145  -37.6368     37.40        81          90
# 9         Vodyane      UA  47.4875   34.4924     46.47        66         100
#
#    Wind Speed Weather Description
# 0       16.11          few clouds
# 1       15.03    scattered clouds
# 2        9.53    scattered clouds
# 3        1.01     overcast clouds
# 4       14.97          light rain
# 5       19.57          light rain
# 6       14.83     overcast clouds
# 7       14.97     overcast clouds
# 8       14.97          light rain
# 9        8.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
